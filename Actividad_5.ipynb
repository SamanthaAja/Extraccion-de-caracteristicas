# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("MexicoCity_Sin_Atipicos.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26067 entries, 0 to 26066
# Data columns (total 50 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    26067 non-null  int64
#  1   host_response_time                            26067 non-null  object
#  2   host_response_rate                            26067 non-null  int64
#  3   host_is_superhost                             26067 non-null  object
#  4   host_location                                 26067 non-null  object
#  5   host_has_profile_pic                          26067 non-null  object
#  6   host_identity_verified                        26067 non-null  object
#  7   neighbourhood_cleansed                        26067 non-null  object
#  8   property_type                                 26067 non-null  object
#  9   room_type                                     26067 non-null  object
#  10  amenities                                     26067 non-null  object
#  11  has_availability                              26067 non-null  object
#  12  instant_bookable                              26067 non-null  object
#  13  host_response_rate.1                          26067 non-null  int64
#  14  host_acceptance_rate                          26067 non-null  int64
#  15  latitude                                      26067 non-null  float64
#  16  longitude                                     26067 non-null  float64
#  17  accommodates                                  26067 non-null  int64
#  18  bathrooms                                     26067 non-null  float64
#  19  bedrooms                                      26067 non-null  int64
#  20  beds                                          26067 non-null  int64
#  21  price                                         26067 non-null  float64
#  22  minimum_nights                                26067 non-null  int64
#  23  maximum_nights                                26067 non-null  int64
#  24  minimum_minimum_nights                        26067 non-null  int64
#  25  maximum_minimum_nights                        26067 non-null  int64
#  26  minimum_maximum_nights                        26067 non-null  int64
#  27  maximum_maximum_nights                        26067 non-null  int64
#  28  minimum_nights_avg_ntm                        26067 non-null  float64
#  29  maximum_nights_avg_ntm                        26067 non-null  float64
#  30  availability_30                               26067 non-null  int64
#  31  availability_60                               26067 non-null  int64
#  32  availability_90                               26067 non-null  int64
#  33  availability_365                              26067 non-null  int64
#  34  number_of_reviews                             26067 non-null  int64
#  35  number_of_reviews_ltm                         26067 non-null  int64
#  36  number_of_reviews_l30d                        26067 non-null  int64
#  37  number_of_reviews_ly                          26067 non-null  int64
#  38  estimated_occupancy_l365d                     26067 non-null  int64
#  39  estimated_revenue_l365d                       26067 non-null  float64
#  40  review_scores_rating                          26067 non-null  float64
#  41  review_scores_accuracy                        26067 non-null  float64
#  42  review_scores_cleanliness                     26067 non-null  float64
#  43  review_scores_checkin                         26067 non-null  float64
#  44  review_scores_communication                   26067 non-null  float64
#  45  review_scores_location                        26067 non-null  float64
#  46  review_scores_value                           26067 non-null  float64
#  47  calculated_host_listings_count                26067 non-null  int64
#  48  calculated_host_listings_count_entire_homes   26067 non-null  int64
#  49  calculated_host_listings_count_private_rooms  26067 non-null  int64
# dtypes: float64(14), int64(25), object(11)
# memory usage: 9.9+ MB

# %%
df.head()
# Out:
#    Unnamed: 0  host_response_time  host_response_rate host_is_superhost  \
# 0           0             Unknown                   0                 f
# 1           1  within a few hours                 100                 f
# 2           2        within a day                  88                 f
# 3           3      within an hour                 100                 t
# 4           4  within a few hours                 100                 t
#
#          host_location host_has_profile_pic host_identity_verified  \
# 0  Mexico City, Mexico                    t                      t
# 1  Mexico City, Mexico                    t                      t
# 2  Mexico City, Mexico                    t                      t
# 3  Mexico City, Mexico                    t                      t
# 4  Mexico City, Mexico                    t                      t
#
#   neighbourhood_cleansed       property_type        room_type  ...  \
# 0  Cuajimalpa de Morelos        Entire villa  Entire home/apt  ...
# 1             Cuauhtémoc         Entire home  Entire home/apt  ...
# 2             Cuauhtémoc        Entire condo  Entire home/apt  ...
# 3             Cuauhtémoc  Entire rental unit  Entire home/apt  ...
# 4               Coyoacán  Entire rental unit  Entire home/apt  ...
#
#   review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 0                 4.80                   4.90                      4.90
# 1                 4.59                   4.56                      4.70
# 2                 4.87                   4.95                      4.88
# 3                 4.90                   4.82                      4.76
# 4                 4.92                   4.91                      4.96
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   4.90                         4.90                    4.90
# 1                   4.87                         4.78                    4.98
# 2                   4.98                         4.94                    4.76
# 3                   4.94                         4.92                    4.98
# 4                   4.96                         4.98                    4.96
#
#    review_scores_value  calculated_host_listings_count  \
# 0                 4.80                               1
# 1                 4.47                               9
# 2                 4.79                               1
# 3                 4.92                               2
# 4                 4.92                               3
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            4
# 2                                            1
# 3                                            2
# 4                                            2
#
#    calculated_host_listings_count_private_rooms
# 0                                             0
# 1                                             2
# 2                                             0
# 3                                             0
# 4                                             1
#
# [5 rows x 50 columns]

# %%
tabla_freq = df['host_response_time'].value_counts().reset_index()
print(tabla_freq)

filtro = tabla_freq[tabla_freq['count'] > 1000]

filtro.plot(kind='bar', x='host_response_time', y='count', legend=False, color=['slateblue', 'teal', 'mediumorchid', 'darkmagenta', 'midnightblue'])
plt.title('Host response time')
plt.ylabel('Frecuencia')
# Out:
#    host_response_time  count
# 0      within an hour  18390
# 1             Unknown   3504
# 2  within a few hours   1990
# 3        within a day   1128
# 4  a few days or more   1055
# Text(0, 0.5, 'Frecuencia')

# %%
tabla_freq = df['host_is_superhost'].value_counts().reset_index()
print(tabla_freq)

filtro = tabla_freq[tabla_freq['count'] > 1000]

filtro_index = filtro.set_index('host_is_superhost')
filtro_index['count'].plot(kind='pie', figsize=(10, 5), autopct='%1.1f%%', colors=['slateblue', 'teal'])
plt.title('Host is Superhost')
plt.ylabel('Frecuencia')
# Out:
#   host_is_superhost  count
# 0                 f  16592
# 1                 t   9475
# Text(0, 0.5, 'Frecuencia')

# %%
tabla_freq = df['host_has_profile_pic'].value_counts().reset_index()
print(tabla_freq)

filtro = tabla_freq[tabla_freq['count'] > 1]

filtro_index = filtro.set_index('host_has_profile_pic')
filtro_index['count'].plot(kind='pie', figsize=(10, 5), autopct='%1.1f%%', colors=['slateblue', 'teal'])
plt.title('Host has Profile Picture')
plt.ylabel('Frecuencia')
# Out:
#   host_has_profile_pic  count
# 0                    t  25529
# 1                    f    538
# Text(0, 0.5, 'Frecuencia')

# %%
tabla_freq = df['host_identity_verified'].value_counts().reset_index()
print(tabla_freq)

filtro = tabla_freq[tabla_freq['count'] > 1]

filtro_index = filtro.set_index('host_identity_verified')
filtro_index['count'].plot(kind='pie', figsize=(10, 5), autopct='%1.1f%%', colors=['slateblue', 'teal'])
plt.title('Host Identity Verified')
plt.ylabel('Frecuencia')
# Out:
#   host_identity_verified  count
# 0                      t  24864
# 1                      f   1203
# Text(0, 0.5, 'Frecuencia')

# %%
tabla_freq = df['property_type'].value_counts().reset_index()
print(tabla_freq)

filtro = tabla_freq[tabla_freq['count'] > 1000]

filtro.plot(kind='bar', x='property_type', y='count', legend=False, color=['slateblue', 'teal', 'mediumorchid', 'darkmagenta', 'midnightblue'])
plt.title('Property Type')
plt.ylabel('Frecuencia')
plt.xticks(rotation=45, ha='right')
# Out:
#                      property_type  count
# 0               Entire rental unit  10024
# 1                     Entire condo   3270
# 2      Private room in rental unit   2994
# 3             Private room in home   2270
# 4                      Entire loft   1497
# ..                             ...    ...
# 77          Private room in resort      1
# 78  Shared room in casa particular      1
# 79           Private room in minsu      1
# 80                           Tower      1
# 81             Shared room in loft      1
#
# [82 rows x 2 columns]
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'Entire rental unit'),
#   Text(1, 0, 'Entire condo'),
#   Text(2, 0, 'Private room in rental unit'),
#   Text(3, 0, 'Private room in home'),
#   Text(4, 0, 'Entire loft')])

# %%
tabla_freq = df['room_type'].value_counts().reset_index()
print(tabla_freq)

filtro = tabla_freq[tabla_freq['count'] > 1 ]

filtro.plot(kind='bar', x='room_type', y='count', legend=False, color=['slateblue', 'teal', 'mediumorchid', 'darkmagenta', 'midnightblue'])
plt.title('Room Type')
plt.ylabel('Frecuencia')
plt.xticks(rotation=45, ha='right')
# Out:
#          room_type  count
# 0  Entire home/apt  17163
# 1     Private room   8646
# 2      Shared room    170
# 3       Hotel room     88
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Entire home/apt'),
#   Text(1, 0, 'Private room'),
#   Text(2, 0, 'Shared room'),
#   Text(3, 0, 'Hotel room')])

# %%
tabla_freq = df['has_availability'].value_counts().reset_index()
print(tabla_freq)

filtro = tabla_freq[tabla_freq['count'] > 1]

filtro_index = filtro.set_index('has_availability')
filtro_index['count'].plot(kind='pie', figsize=(10, 5), autopct='%1.1f%%', colors=['slateblue', 'teal'])
plt.title('Host has Availability')
plt.ylabel('Frecuencia')
# Out:
#   has_availability  count
# 0                t  25076
# 1                f    991
# Text(0, 0.5, 'Frecuencia')

# %%
pat_cdmx = r'(ciudad\s+de\s+m[ée]xico|cdmx|mexico\s+city|m[ée]xico\s*,?\s*d\.?\s*f\.?)'

# Colapsa TODAS las filas que contengan alguna variante a una sola etiqueta
mask = df['host_location'].str.contains(pat_cdmx, case=False, na=False, regex=True)
df.loc[mask, 'host_location'] = 'CDMX'

# Opcional: normaliza Unknown
df['host_location'] = df['host_location'].fillna('Unknown')
df['host_location'] = df['host_location'].replace(r'^\s*(nan|none|unknown)?\s*$', 'Unknown', regex=True)

# Recuenta y grafica
filtro = df['host_location'].value_counts().reset_index()
filtro.columns = ['host_location', 'count']
filtro = filtro[filtro['count'] > 200]

ax = filtro.plot(kind='bar', x='host_location', y='count', legend=False, color=['slateblue', 'teal', 'mediumorchid', 'darkmagenta', 'midnightblue'])
ax.set_title('Host Location')
ax.set_ylabel('Frecuencia')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# Out:
# C:\Users\ajasa\AppData\Local\Temp\ipykernel_26420\1230182959.py:4: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask = df['host_location'].str.contains(pat_cdmx, case=False, na=False, regex=True)
# [Text(0, 0, 'CDMX'),
#  Text(1, 0, 'Unknown'),
#  Text(2, 0, 'Mexico'),
#  Text(3, 0, 'New York, NY')]

# %%
tabla_freq = df['neighbourhood_cleansed'].value_counts().reset_index()
print(tabla_freq)

filtro = tabla_freq[tabla_freq['count'] > 1000]

filtro.plot(kind='bar', x='neighbourhood_cleansed', y='count', legend=False, color=['slateblue', 'teal', 'mediumorchid', 'darkmagenta', 'midnightblue'])
plt.title('Neighbourhood Cleansed')
plt.ylabel('Frecuencia')
plt.xticks(rotation=45, ha='right')
# Out:
#     neighbourhood_cleansed  count
# 0               Cuauhtémoc  12030
# 1           Miguel Hidalgo   4441
# 2            Benito Juárez   2989
# 3                 Coyoacán   1693
# 4           Álvaro Obregón   1007
# 5      Venustiano Carranza    838
# 6                  Tlalpan    777
# 7        Gustavo A. Madero    479
# 8    Cuajimalpa de Morelos    424
# 9                Iztacalco    421
# 10            Azcapotzalco    362
# 11              Iztapalapa    263
# 12              Xochimilco    139
# 13  La Magdalena Contreras    131
# 14                 Tláhuac     43
# 15              Milpa Alta     30
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'Cuauhtémoc'),
#   Text(1, 0, 'Miguel Hidalgo'),
#   Text(2, 0, 'Benito Juárez'),
#   Text(3, 0, 'Coyoacán'),
#   Text(4, 0, 'Álvaro Obregón')])

# %%
tabla_freq = df['instant_bookable'].value_counts().reset_index()
print(tabla_freq)

filtro = tabla_freq[tabla_freq['count'] > 1]

filtro_index = filtro.set_index('instant_bookable')
filtro_index['count'].plot(kind='pie', figsize=(10, 5), autopct='%1.1f%%', colors=['slateblue', 'teal'])
plt.title('Instant Bookable')
plt.ylabel('Frecuencia')
# Out:
#   instant_bookable  count
# 0                f  15666
# 1                t  10401
# Text(0, 0.5, 'Frecuencia')

# %%
df['host_response_rate'].info()
n=171

max1=df['host_response_rate'].max()
min1=df['host_response_rate'].min()
limites = (min1, max1)   
limites

R = max1 - min1
R

ni = 1+3.32*np.log10(n)
ni  

i = R/ni
i

intervalos1 = np.linspace(-1, 100.1, 6)
intervalos1

categorias = ['Malo', 'Regular', 'Bueno', 'Muy Bueno', 'Excelente']

df['host_response_rate'] = pd.cut(x= df['host_response_rate'], bins=intervalos1, labels= categorias)
df['host_response_rate']
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26067 entries, 0 to 26066
# Series name: host_response_rate
# Non-Null Count  Dtype
# --------------  -----
# 26067 non-null  int64
# dtypes: int64(1)
# memory usage: 203.8 KB
# 0             Malo
# 1        Excelente
# 2        Excelente
# 3        Excelente
# 4        Excelente
#            ...
# 26062    Excelente
# 26063    Excelente
# 26064    Excelente
# 26065    Excelente
# 26066         Malo
# Name: host_response_rate, Length: 26067, dtype: category
# Categories (5, object): ['Malo' < 'Regular' < 'Bueno' < 'Muy Bueno' < 'Excelente']

# %%
df['accommodates'].info()
n=171

unicos = df['accommodates'].unique()
print(unicos)

max1=df['accommodates'].max()
min1=df['accommodates'].min()
limites = (min1, max1)   
limites

R = max1 - min1
R

ni = 1+3.32*np.log10(n)
ni  

i = R/ni
print(i)

intervalos1 = np.linspace(-1, 7, 6)
intervalos1

categorias = ['1-2', '3', '4', '5', '6-7']

df['accommodates'] = pd.cut(x= df['accommodates'], bins=intervalos1, labels= categorias)
df['accommodates']
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26067 entries, 0 to 26066
# Series name: accommodates
# Non-Null Count  Dtype
# --------------  -----
# 26067 non-null  int64
# dtypes: int64(1)
# memory usage: 203.8 KB
# [2 4 1 3 7 5 6]
# 0.7131356059831103
# 0          3
# 1          3
# 2          3
# 3          5
# 4          3
#         ...
# 26062      5
# 26063      3
# 26064      3
# 26065      3
# 26066    6-7
# Name: accommodates, Length: 26067, dtype: category
# Categories (5, object): ['1-2' < '3' < '4' < '5' < '6-7']

# %%
df['price'].info()
n=171

max1=df['price'].max()
min1=df['price'].min()
limites = (min1, max1)   
limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26067 entries, 0 to 26066
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 26067 non-null  float64
# dtypes: float64(1)
# memory usage: 203.8 KB
# (np.float64(116.0), np.float64(3287.0))

# %%
R = max1 - min1
R

ni = 1+3.32*np.log10(n)
ni  

i = R/ni
i

intervalos1 = np.linspace(115, 3288, 6)
intervalos1

categorias = ['116-600', '601-1,086', '1,087-1,573', '1,574-2,060', '2,061-3,288']

df['price'] = pd.cut(x= df['price'], bins=intervalos1, labels= categorias)
df['price']
# Out:
# 0          601-1,086
# 1          601-1,086
# 2            116-600
# 3          601-1,086
# 4          601-1,086
#             ...
# 26062        116-600
# 26063        116-600
# 26064        116-600
# 26065    1,087-1,573
# 26066    1,087-1,573
# Name: price, Length: 26067, dtype: category
# Categories (5, object): ['116-600' < '601-1,086' < '1,087-1,573' < '1,574-2,060' < '2,061-3,288']

# %%
df['host_acceptance_rate'].info()
n=171

max1=df['host_acceptance_rate'].max()
min1=df['host_acceptance_rate'].min()
limites = (min1, max1)   
limites
pd.Series(limites).value_counts()
print(pd.Series(limites).value_counts())
print("los limites son: ", limites)

R = max1 - min1
R

ni = 1+3.32*np.log10(n)
ni  

i = R/ni
i

intervalos1 = np.linspace(89, 101, 6)
intervalos1

categorias = ['Malo', 'Regular', 'Bueno', 'Muy Bueno', 'Excelente']

df['host_acceptance_rate'] = pd.cut(x= df['host_acceptance_rate'], bins=intervalos1, labels= categorias)
df['host_acceptance_rate']

tabla_freq = df['host_acceptance_rate'].value_counts().reset_index()
print(tabla_freq)

filtro_index = tabla_freq.set_index('host_acceptance_rate')
filtro_index['count'].plot(kind='pie', figsize=(10, 5), autopct='%1.1f%%', colors=['slateblue', 'teal', 'mediumorchid', 'darkmagenta', 'midnightblue'])
plt.title('Host Acceptance Rate')
plt.ylabel('Frecuencia')
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26067 entries, 0 to 26066
# Series name: host_acceptance_rate
# Non-Null Count  Dtype
# --------------  -----
# 26067 non-null  int64
# dtypes: int64(1)
# memory usage: 203.8 KB
# 90     1
# 100    1
# Name: count, dtype: int64
# los limites son:  (np.int64(90), np.int64(100))
#   host_acceptance_rate  count
# 0            Excelente  21507
# 1            Muy Bueno   2308
# 2                Bueno   1256
# 3              Regular    591
# 4                 Malo    405
# Text(0, 0.5, 'Frecuencia')

# %%
tabla_freq = df['host_response_rate'].value_counts().reset_index()
print(tabla_freq)

filtro = tabla_freq[tabla_freq['count'] > 0]

filtro.plot(kind='bar', x='host_response_rate', y='count', legend=False, color=['slateblue', 'teal', 'mediumorchid', 'darkmagenta', 'midnightblue'])
plt.title('Host Response Rate')
plt.ylabel('Frecuencia')
plt.xticks(rotation=45, ha='right')
# Out:
#   host_response_rate  count
# 0          Excelente  20880
# 1               Malo   4306
# 2          Muy Bueno    453
# 3              Bueno    225
# 4            Regular    203
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'Excelente'),
#   Text(1, 0, 'Malo'),
#   Text(2, 0, 'Muy Bueno'),
#   Text(3, 0, 'Bueno'),
#   Text(4, 0, 'Regular')])

# %%
tabla_freq = df['accommodates'].value_counts().reset_index()
print(tabla_freq)

filtro = tabla_freq[tabla_freq['count'] > 1]

filtro_index = filtro.set_index('accommodates')
filtro_index['count'].plot(kind='pie', figsize=(10, 5), autopct='%1.1f%%', colors=['slateblue', 'teal', 'mediumorchid', 'darkmagenta', 'midnightblue'])
plt.title('Accommodates Value')
plt.ylabel('Frecuencia')
# Out:
#   accommodates  count
# 0            3  14657
# 1            5   6941
# 2            4   2373
# 3          6-7   2096
# 4          1-2      0
# Text(0, 0.5, 'Frecuencia')

# %%
tabla_freq = df['price'].value_counts().reset_index()
print(tabla_freq)

filtro = tabla_freq[tabla_freq['count'] > 0]

filtro.plot(kind='bar', x='price', y='count', legend=False, color=['slateblue', 'teal', 'mediumorchid', 'darkmagenta', 'midnightblue'])
plt.title('Price Distribution')
plt.ylabel('Frecuencia')
plt.xticks(rotation=45, ha='right')
# Out:
#          price  count
# 0    601-1,086  11824
# 1      116-600   7342
# 2  1,087-1,573   3692
# 3  1,574-2,060   2148
# 4  2,061-3,288   1061
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, '601-1,086'),
#   Text(1, 0, '116-600'),
#   Text(2, 0, '1,087-1,573'),
#   Text(3, 0, '1,574-2,060'),
#   Text(4, 0, '2,061-3,288')])

# %%
df['bathrooms'].info()
n=171

max1=df['bathrooms'].max()
min1=df['bathrooms'].min()
limites = (min1, max1)   
limites
pd.Series(limites).value_counts()
print(pd.Series(limites).value_counts())
print("los limites son: ", limites)

R = max1 - min1
R

ni = 1+3.32*np.log10(n)
ni  

i = R/ni
i

intervalos1 = np.linspace(0, 3.6, 5)
intervalos1

categorias = ['1 baño', '2 baños', '3 baños', '4 baños']

df['bathrooms'] = pd.cut(x= df['bathrooms'], bins=intervalos1, labels= categorias)
df['bathrooms']

tabla_freq = df['bathrooms'].value_counts().reset_index()
print(tabla_freq)

filtro_index = tabla_freq.set_index('bathrooms')
filtro_index['count'].plot(kind='pie', figsize=(10, 5), autopct='%1.1f%%', colors=['slateblue', 'teal', 'mediumorchid', 'darkmagenta', 'midnightblue'])
plt.title('Bathrooms')
plt.ylabel('Frecuencia')
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26067 entries, 0 to 26066
# Series name: bathrooms
# Non-Null Count  Dtype
# --------------  -----
# 26067 non-null  float64
# dtypes: float64(1)
# memory usage: 203.8 KB
# 0.0    1
# 3.5    1
# Name: count, dtype: int64
# los limites son:  (np.float64(0.0), np.float64(3.5))
#   bathrooms  count
# 0   2 baños  19353
# 1   3 baños   5654
# 2   4 baños    858
# 3    1 baño     85
# Text(0, 0.5, 'Frecuencia')

# %%
df['beds'].info()
n=171

max1=df['beds'].max()
min1=df['beds'].min()
limites = (min1, max1)   
limites
pd.Series(limites).value_counts()
print(pd.Series(limites).value_counts())
print("los limites son: ", limites)

R = max1 - min1
R

ni = 1+3.32*np.log10(n)
ni  

i = R/ni
i

intervalos1 = np.linspace(0, 4, 4)
intervalos1

categorias = ['1 cama', '2 camas', '3 camas']

df['beds'] = pd.cut(x= df['beds'], bins=intervalos1, labels= categorias)
df['beds']

tabla_freq = df['beds'].value_counts().reset_index()
print(tabla_freq)

filtro_index = tabla_freq.set_index('beds')
filtro_index['count'].plot(kind='pie', figsize=(10, 5), autopct='%1.1f%%', colors=['slateblue', 'teal', 'mediumorchid', 'darkmagenta', 'midnightblue'])
plt.title('Beds')
plt.ylabel('Frecuencia')
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26067 entries, 0 to 26066
# Series name: beds
# Non-Null Count  Dtype
# --------------  -----
# 26067 non-null  int64
# dtypes: int64(1)
# memory usage: 203.8 KB
# 0    1
# 3    1
# Name: count, dtype: int64
# los limites son:  (np.int64(0), np.int64(3))
#       beds  count
# 0   1 cama  17035
# 1  2 camas   5982
# 2  3 camas   2673
# Text(0, 0.5, 'Frecuencia')

# %%
df['maximum_nights_avg_ntm'].info()
n=171

max1=df['maximum_nights_avg_ntm'].max()
min1=df['maximum_nights_avg_ntm'].min()
limites = (min1, max1)   
limites
pd.Series(limites).value_counts()
print(pd.Series(limites).value_counts())
print("los limites son: ", limites)

intervalos1 = np.linspace(0, 1270.2, 6)
intervalos1
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26067 entries, 0 to 26066
# Series name: maximum_nights_avg_ntm
# Non-Null Count  Dtype
# --------------  -----
# 26067 non-null  float64
# dtypes: float64(1)
# memory usage: 203.8 KB
# 1.0       1
# 1270.1    1
# Name: count, dtype: int64
# los limites son:  (np.float64(1.0), np.float64(1270.1))
# array([   0.  ,  254.04,  508.08,  762.12, 1016.16, 1270.2 ])

# %%
R = max1 - min1
R

ni = 1+3.32*np.log10(n)
ni  

i = R/ni
i

intervalos1 = np.linspace(0, 1270.2, 6)
intervalos1

categorias = ['1-254', '255-508', '509-762', '763-1016', '1017-1270']

df['maximum_nights_avg_ntm'] = pd.cut(x= df['maximum_nights_avg_ntm'], bins=intervalos1, labels= categorias)
df['maximum_nights_avg_ntm']

filtro = tabla_freq[tabla_freq['count'] > 1]
filtro
tabla_freq = df['maximum_nights_avg_ntm'].value_counts().reset_index()
print(tabla_freq)

df['maximum_nights_avg_ntm'].value_counts().plot(
    kind='bar',
    color=['slateblue', 'teal', 'mediumorchid', 'darkmagenta', 'midnightblue']
)
plt.title('Maximum Nights Avg NTM Distribution')
plt.ylabel('Frecuencia')
plt.show()
# Out:
#   maximum_nights_avg_ntm  count
# 0              1017-1270  12916
# 1                255-508   8160
# 2                  1-254   4206
# 3                509-762    502
# 4               763-1016    283

# %%
df['availability_365'].info()
n=171

max1=df['availability_365'].max()
min1=df['availability_365'].min()
limites = (min1, max1)   
limites
pd.Series(limites).value_counts()
print(pd.Series(limites).value_counts())
print("los limites son: ", limites)

intervalos1 = np.linspace(0, 365.1, 6)
intervalos1
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26067 entries, 0 to 26066
# Series name: availability_365
# Non-Null Count  Dtype
# --------------  -----
# 26067 non-null  int64
# dtypes: int64(1)
# memory usage: 203.8 KB
# 0      1
# 365    1
# Name: count, dtype: int64
# los limites son:  (np.int64(0), np.int64(365))
# array([  0.  ,  73.02, 146.04, 219.06, 292.08, 365.1 ])

# %%
R = max1 - min1
R

ni = 1+3.32*np.log10(n)
ni  

i = R/ni
i

intervalos1 = np.linspace(0, 365.1, 6)
intervalos1

categorias = ['1-73', '74-146', '147-219', '220-292', '293-365']

df['availability_365'] = pd.cut(x= df['availability_365'], bins=intervalos1, labels= categorias)
df['availability_365']

filtro = tabla_freq[tabla_freq['count'] > 1]
filtro
tabla_freq = df['availability_365'].value_counts().reset_index()
print(tabla_freq)

df['availability_365'].value_counts().plot(
    kind='bar',
    color=['slateblue', 'teal', 'mediumorchid', 'darkmagenta', 'midnightblue']
)
plt.title('Availability 365 Distribution')
plt.ylabel('Frecuencia')
plt.show()
# Out:
#   availability_365  count
# 0          293-365  10870
# 1          220-292   3936
# 2           74-146   2985
# 3          147-219   2970
# 4             1-73   2734

# %%
df['number_of_reviews'].info()
n=171

max1=df['number_of_reviews'].max()
min1=df['number_of_reviews'].min()
limites = (min1, max1)   
limites
pd.Series(limites).value_counts()
print(pd.Series(limites).value_counts())
print("los limites son: ", limites)
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26067 entries, 0 to 26066
# Series name: number_of_reviews
# Non-Null Count  Dtype
# --------------  -----
# 26067 non-null  int64
# dtypes: int64(1)
# memory usage: 203.8 KB
# 0      1
# 154    1
# Name: count, dtype: int64
# los limites son:  (np.int64(0), np.int64(154))

# %%
intervalos1 = np.linspace(0, 154, 6)
intervalos1
# Out:
# array([  0. ,  30.8,  61.6,  92.4, 123.2, 154. ])

# %%
R = max1 - min1
R

ni = 1+3.32*np.log10(n)
ni  

i = R/ni
i

intervalos1 = np.linspace(0, 154, 6)
intervalos1

categorias = ['1-30', '31-61', '62-92', '93-123', '124-154']

df['number_of_reviews'] = pd.cut(x= df['number_of_reviews'], bins=intervalos1, labels= categorias)
df['number_of_reviews']

filtro = tabla_freq[tabla_freq['count'] > 1]
filtro
tabla_freq = df['number_of_reviews'].value_counts().reset_index()
print(tabla_freq)

df['number_of_reviews'].value_counts().plot(
    kind='bar',
    color=['slateblue', 'teal', 'mediumorchid', 'darkmagenta', 'midnightblue']
)
plt.title('Number of Reviews')
plt.ylabel('Frecuencia')
plt.show()
# Out:
#   number_of_reviews  count
# 0              1-30  14270
# 1             31-61   3918
# 2             62-92   2289
# 3            93-123   1397
# 4           124-154    932

# %%
df['review_scores_value'].info()
n=171

max1=df['review_scores_value'].max()
min1=df['review_scores_value'].min()
limites = (min1, max1)   
limites
pd.Series(limites).value_counts()
print(pd.Series(limites).value_counts())
print("los limites son: ", limites)
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26067 entries, 0 to 26066
# Series name: review_scores_value
# Non-Null Count  Dtype
# --------------  -----
# 26067 non-null  float64
# dtypes: float64(1)
# memory usage: 203.8 KB
# 3.9    1
# 5.0    1
# Name: count, dtype: int64
# los limites son:  (np.float64(3.9), np.float64(5.0))

# %%
R = max1 - min1
R

ni = 1+3.32*np.log10(n)
ni  

i = R/ni
i

intervalos1 = np.linspace(3.8, 5.1, 6)
intervalos1

categorias = ['Malo', 'Regular', 'Bueno', 'Muy Bueno', 'Excelente']

df['review_scores_value'] = pd.cut(x= df['review_scores_value'], bins=intervalos1, labels= categorias)
df['review_scores_value']

filtro = tabla_freq[tabla_freq['count'] > 1]
filtro
tabla_freq = df['review_scores_value'].value_counts().reset_index()
print(tabla_freq)

filtro_index = tabla_freq.set_index('review_scores_value')
filtro_index['count'].plot(kind='pie', figsize=(10, 5), autopct='%1.1f%%', colors=['slateblue', 'teal', 'mediumorchid', 'darkmagenta', 'midnightblue'])
plt.title('Review Scores')
plt.ylabel('Frecuencia')
# Out:
#   review_scores_value  count
# 0           Muy Bueno  13407
# 1           Excelente   9140
# 2               Bueno   2474
# 3             Regular    532
# 4                Malo    514
# Text(0, 0.5, 'Frecuencia')
